# %% [markdown]
# # GPT

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 40.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 39.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 9.5 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
new=pipeline('text-generation',model='gpt2')

# %%
new("India is a country where population is high",max_length=20,num_return_sequences=5)
# Out:
# /usr/local/lib/python3.9/dist-packages/transformers/generation/utils.py:1201: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation)
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'India is a country where population is high. But while almost half (45%) say they are more'},
#  {'generated_text': 'India is a country where population is high; where there\'s an economic problem that can be resolved,"'},
#  {'generated_text': 'India is a country where population is high – a population many argue makes it more attractive for companies that'},
#  {'generated_text': "India is a country where population is high, but you'd be forgiven if we don't have some"},
# ...

# %% [markdown]
# # BERT

# %%
new1=pipeline("fill-mask",model='bert-base-uncased')
# Out:
# ...
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
new1("My day was [MASK].")
# Out:
# [{'score': 0.15079939365386963,
#   'token': 2058,
#   'token_str': 'over',
#   'sequence': 'my day was over.'},
#  {'score': 0.08346705883741379,
#   'token': 5697,
#   'token_str': 'busy',
#   'sequence': 'my day was busy.'},
#  {'score': 0.07708539068698883,
#   'token': 2204,
#   'token_str': 'good',
#   'sequence': 'my day was good.'},
#  {'score': 0.04883769154548645,
#   'token': 3819,
#   'token_str': 'perfect',
#   'sequence': 'my day was perfect.'},
#  {'score': 0.03755072131752968,
#   'token': 2307,
#   'token_str': 'great',
#   'sequence': 'my day was great.'}]

# %% [markdown]
# # XLM

# %%
new2=pipeline("fill-mask",model='xlm-roberta-base')

# %%
new2("motor bike is a <mask> model.")
# Out:
# [{'score': 0.09480088204145432,
#   'token': 3525,
#   'token_str': 'new',
#   'sequence': 'motor bike is a new model.'},
#  {'score': 0.041649606078863144,
#   'token': 54704,
#   'token_str': 'classic',
#   'sequence': 'motor bike is a classic model.'},
#  {'score': 0.02897358126938343,
#   'token': 12921,
#   'token_str': 'different',
#   'sequence': 'motor bike is a different model.'},
#  {'score': 0.01935150846838951,
#   'token': 4127,
#   'token_str': 'good',
#   'sequence': 'motor bike is a good model.'},
#  {'score': 0.015182048082351685,
#   'token': 75796,
#   'token_str': 'vintage',
#   'sequence': 'motor bike is a vintage model.'}]
